# %%
from IPython.display import HTML
HTML('<style>body { background-image: url("images/oly.webp");}</style>')
# Out:
# <style>body { background-image: url("images/oly.webp");}</style>

# %% [markdown]
#
#  <h1 style="text-align:center;color:#0930F0;">Projet analyse de données by asma</h1>

# %% [markdown]
# <h2><span style="color:#606372;">TITLED: </span>"Olympics Althlete Events Analysis"</h2>

# %%
from IPython.display import Image
Image(filename='images/olympic_rings.png')

# %% [markdown]
# <h1 style="color:#AF1010;"> I-Importing packages</h1>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
#  <h1 style="color:#AF1010;">II-Extracting valuable information from the dataset</h1>

# %%
olympics= pd.read_csv("data/athlete_events.csv")
olympics
# Out:
#             id                      name sex   age  height  weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   team  noc        games  year  season            city  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# 1                China  CHN  2012 Summer  2012  Summer          London
# 2              Denmark  DEN  1920 Summer  1920  Summer       Antwerpen
# 3       Denmark/Sweden  DEN  1900 Summer  1900  Summer           Paris
# 4          Netherlands  NED  1988 Winter  1988  Winter         Calgary
# ...                ...  ...          ...   ...     ...             ...
# 271111        Poland-1  POL  1976 Winter  1976  Winter       Innsbruck
# 271112          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271113          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271114          Poland  POL  1998 Winter  1998  Winter          Nagano
# 271115          Poland  POL  2002 Winter  2002  Winter  Salt Lake City
#
#                 sport                                     event medal
# 0          Basketball               Basketball Men's Basketball   NaN
# 1                Judo              Judo Men's Extra-Lightweight   NaN
# 2            Football                   Football Men's Football   NaN
# 3          Tug-Of-War               Tug-Of-War Men's Tug-Of-War  Gold
# 4       Speed Skating          Speed Skating Women's 500 metres   NaN
# ...               ...                                       ...   ...
# 271111           Luge                Luge Mixed (Men)'s Doubles   NaN
# 271112    Ski Jumping  Ski Jumping Men's Large Hill, Individual   NaN
# 271113    Ski Jumping        Ski Jumping Men's Large Hill, Team   NaN
# 271114      Bobsleigh                      Bobsleigh Men's Four   NaN
# 271115      Bobsleigh                      Bobsleigh Men's Four   NaN
#
# [271116 rows x 15 columns]

# %% [markdown]
# <h2 style="color:#D4640E;">1)Checking The Shape of The Dataframe</h2>

# %%
olympics.head()
# Out:
#    id                      name sex   age  height  weight            team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    noc        games  year  season       city          sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               event medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %%
olympics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      271116 non-null  int64
#  1   name    271116 non-null  object
#  2   sex     271116 non-null  object
#  3   age     261642 non-null  float64
#  4   height  210945 non-null  float64
#  5   weight  208241 non-null  float64
#  6   team    271116 non-null  object
#  7   noc     271116 non-null  object
#  8   games   271116 non-null  object
#  9   year    271116 non-null  int64
#  10  season  271116 non-null  object
#  11  city    271116 non-null  object
#  12  sport   271116 non-null  object
#  13  event   271116 non-null  object
#  14  medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
print(olympics.head().to_markdown())
# Out:
# |    |   id | name                     | sex   |   age |   height |   weight | team           | noc   | games       |   year | season   | city      | sport         | event                            | medal   |
# |---:|-----:|:-------------------------|:------|------:|---------:|---------:|:---------------|:------|:------------|-------:|:---------|:----------|:--------------|:---------------------------------|:--------|
# |  0 |    1 | A Dijiang                | M     |    24 |      180 |       80 | China          | CHN   | 1992 Summer |   1992 | Summer   | Barcelona | Basketball    | Basketball Men's Basketball      | nan     |
# |  1 |    2 | A Lamusi                 | M     |    23 |      170 |       60 | China          | CHN   | 2012 Summer |   2012 | Summer   | London    | Judo          | Judo Men's Extra-Lightweight     | nan     |
# |  2 |    3 | Gunnar Nielsen Aaby      | M     |    24 |      nan |      nan | Denmark        | DEN   | 1920 Summer |   1920 | Summer   | Antwerpen | Football      | Football Men's Football          | nan     |
# |  3 |    4 | Edgar Lindenau Aabye     | M     |    34 |      nan |      nan | Denmark/Sweden | DEN   | 1900 Summer |   1900 | Summer   | Paris     | Tug-Of-War    | Tug-Of-War Men's Tug-Of-War      | Gold    |
# |  4 |    5 | Christine Jacoba Aaftink | F     |    21 |      185 |       82 | Netherlands    | NED   | 1988 Winter |   1988 | Winter   | Calgary   | Speed Skating | Speed Skating Women's 500 metres | nan     |

# %%
#loading and giving the statics to the olympics dataset
olympics.describe()
# Out:
#                   id            age         height         weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
olympics.shape
# Out:
# (271116, 15)

# %% [markdown]
# <h2 style="color:#D4640E;">2)Checking The Null Values</h2>

# %%
print(olympics.isnull().sum())
# Out:
# id             0
# name           0
# sex            0
# age         9474
# height     60171
# weight     62875
# team           0
# noc            0
# games          0
# year           0
# season         0
# city           0
# sport          0
# event          0
# medal     231333
# dtype: int64

# %% [markdown]
# *=>We find that height, weight and Age have a lot of missing values. Medals have a NaN in about 2,31,333 rows. These can be explained since not all participating athletes would win medals. Let's replace these missing values by 'Did not win' or 'DNW'.*

# %%
olympics['medal'].fillna('DNW', inplace = True)

# %%
# As expected the NaNs in the 'medal' column disappear!
print(olympics.isnull().sum())
# Out:
# id            0
# name          0
# sex           0
# age        9474
# height    60171
# weight    62875
# team          0
# noc           0
# games         0
# year          0
# season        0
# city          0
# sport         0
# event         0
# medal         0
# dtype: int64

# %% [markdown]
# <h2 style="color:#D4640E;">3)Checking Duplicated Values</h2>

# %%
olympics.duplicated().sum()
# Out:
# 1385

# %%
olympics.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 271111    False
# 271112    False
# 271113    False
# 271114    False
# 271115    False
# Length: 271116, dtype: bool

# %%
#dealing with the duplicated values
# sorting by first name
olympics.sort_values("id", inplace=True)
  
# dropping ALL duplicate values
olympics.drop_duplicates(subset="id",
                     keep=False, inplace=True)
                     
olympics.duplicated().sum()
# Out:
# 0

# %%
# displaying the data shape
olympics.shape
# Out:
# (77901, 15)

# %% [markdown]
# *=>Athlete_events dataset contains 77901 rows of data and 15 columns, which has individual entries for each athlete:*

# %% [markdown]
# <h2 style="color:#D4640E;">4)Checking The Types Of Data</h2>

# %%
olympics.columns
# Out:
# Index(['id', 'name', 'sex', 'age', 'height', 'weight', 'team', 'noc', 'games',
#        'year', 'season', 'city', 'sport', 'event', 'medal'],
#       dtype='object')

# %%
olympics.dtypes
# Out:
# id          int64
# name       object
# sex        object
# age       float64
# height    float64
# weight    float64
# team       object
# noc        object
# games      object
# year        int64
# season     object
# city       object
# sport      object
# event      object
# medal      object
# dtype: object

# %% [markdown]
# *==>Now we have clean and well-organized dataframe.*

# %% [markdown]
# <h1 style="color:#AF1010"> III-Exploring And Analysing The DataFrame: </h1>

# %% [markdown]
# **In which year and city did the Netherlands win the highest number of medals in their history?**

# %%
# Selecting only netherland team
netherland_data = olympics[olympics['team'] == 'Netherlands']

# %%
print(netherland_data)
# Out:
#             id                                   name sex   age  height  \
# 88          27                          Johan Aantjes   M  26.0     NaN
# 91          29                   Willemien Aardenburg   F  22.0     NaN
# 263        135                           Lois Abbingh   F  23.0   178.0
# 798        456                             Karin Abma   F  24.0   174.0
# 1250       703     Marianne "Marjan" Ackermans-Thomas   F  26.0   180.0
# ...        ...                                    ...  ..   ...     ...
# 271006  135518       Guillaum Franois "Frank" Zweerts   M  21.0   186.0
# 271007  135519    Jeronemus Johannes "Jeroen" Zweerts   M  27.0   183.0
# 271028  135532                   Edward "Eddie" Zwier   M  26.0   176.0
# 271029  135533  Petronella Veronica Maria "Nel" Zwier   F  23.0   174.0
# 271034  135536                      Henri Timo Zwiers   M  36.0     NaN
#
#         weight         team  noc        games  year  season            city  \
# 88         NaN  Netherlands  NED  1984 Summer  1984  Summer     Los Angeles
# 91         NaN  Netherlands  NED  1988 Summer  1988  Summer           Seoul
# 263       72.0  Netherlands  NED  2016 Summer  2016  Summer  Rio de Janeiro
# 798       62.0  Netherlands  NED  1976 Summer  1976  Summer        Montreal
# 1250      70.0  Netherlands  NED  1968 Summer  1968  Summer     Mexico City
# ...        ...          ...  ...          ...   ...     ...             ...
# 271006    84.0  Netherlands  NED  1964 Summer  1964  Summer           Tokyo
# 271007    80.0  Netherlands  NED  1972 Summer  1972  Summer          Munich
# 271028    75.0  Netherlands  NED  1960 Summer  1960  Summer            Roma
# 271029    70.0  Netherlands  NED  1960 Summer  1960  Summer            Roma
# 271034     NaN  Netherlands  NED  1936 Summer  1936  Summer          Berlin
#
#                    sport                                              event  \
# 88            Water Polo                        Water Polo Men's Water Polo
# 91                Hockey                              Hockey Women's Hockey
# 263             Handball                          Handball Women's Handball
# 798               Rowing                        Rowing Women's Coxed Eights
# 1250           Athletics                       Athletics Women's Pentathlon
# ...                  ...                                                ...
# 271006            Hockey                                Hockey Men's Hockey
# 271007            Hockey                                Hockey Men's Hockey
# 271028            Hockey                                Hockey Men's Hockey
# 271029         Athletics                        Athletics Women's High Jump
# 271034  Art Competitions  Art Competitions Mixed Architecture, Architect...
#
#          medal
# 88         DNW
# 91      Bronze
# 263        DNW
# 798        DNW
# 1250       DNW
# ...        ...
# 271006     DNW
# 271007     DNW
# 271028     DNW
# 271029     DNW
# 271034     DNW
#
# [1566 rows x 15 columns]

# %%
# we now grouping data by city and year 
# and then count number of medal of particular year and city
medals_won_each_year_and_city = netherland_data.groupby(['year','city'])['medal'].count()
medals_won_each_year_and_city
# Out:
# year  city
# 1900  Paris                      10
# 1906  Athina                      2
# 1908  London                     40
# 1912  Stockholm                  21
# 1920  Antwerpen                  72
# 1924  Paris                      84
# 1928  Amsterdam                 151
#       Sankt Moritz                5
# 1932  Los Angeles                11
# 1936  Berlin                     94
#       Garmisch-Partenkirchen      4
# 1948  London                     77
# 1952  Helsinki                   42
#       Oslo                        3
# 1956  Cortina d'Ampezzo           1
#       Stockholm                   1
# 1960  Roma                       52
# 1964  Tokyo                      55
# 1968  Mexico City                53
# 1972  Munich                     50
#       Sapporo                     2
# 1976  Innsbruck                   1
#       Montreal                   51
# 1980  Lake Placid                20
#       Moskva                     26
# 1984  Los Angeles                50
#       Sarajevo                    3
# 1988  Seoul                      45
# 1992  Albertville                 2
#       Barcelona                  62
# 1994  Lillehammer                 3
# 1996  Atlanta                    91
# 1998  Nagano                      2
# 2000  Sydney                     77
# 2002  Salt Lake City              2
# 2004  Athina                     54
# 2006  Torino                      2
# 2008  Beijing                    88
# 2010  Vancouver                   5
# 2012  London                     33
# 2014  Sochi                       7
# 2016  Rio de Janeiro            112
# Name: medal, dtype: int64

# %%
# the resultant value will be a series so we are converting it into a dataframe 
labeled_medals_data = medals_won_each_year_and_city.rename('No_of_medals')
final_data = pd.DataFrame(labeled_medals_data)
print(final_data)
# Out:
#                              No_of_medals
# year city
# 1900 Paris                             10
# 1906 Athina                             2
# 1908 London                            40
# 1912 Stockholm                         21
# 1920 Antwerpen                         72
# 1924 Paris                             84
# 1928 Amsterdam                        151
#      Sankt Moritz                       5
# 1932 Los Angeles                       11
# 1936 Berlin                            94
#      Garmisch-Partenkirchen             4
# 1948 London                            77
# 1952 Helsinki                          42
#      Oslo                               3
# 1956 Cortina d'Ampezzo                  1
#      Stockholm                          1
# 1960 Roma                              52
# 1964 Tokyo                             55
# 1968 Mexico City                       53
# 1972 Munich                            50
#      Sapporo                            2
# 1976 Innsbruck                          1
#      Montreal                          51
# 1980 Lake Placid                       20
#      Moskva                            26
# 1984 Los Angeles                       50
#      Sarajevo                           3
# 1988 Seoul                             45
# 1992 Albertville                        2
#      Barcelona                         62
# 1994 Lillehammer                        3
# 1996 Atlanta                           91
# 1998 Nagano                             2
# 2000 Sydney                            77
# 2002 Salt Lake City                     2
# 2004 Athina                            54
# 2006 Torino                             2
# 2008 Beijing                           88
# 2010 Vancouver                          5
# 2012 London                            33
# 2014 Sochi                              7
# 2016 Rio de Janeiro                   112

# %%
# Finally sorted the dataframe by no_of_medals and sort in descending order and selected 1 row
sorted_final_data = final_data.sort_values('No_of_medals',ascending=False).head(1)
sorted_final_data
# Out:
#                 No_of_medals
# year city
# 1928 Amsterdam           151

# %% [markdown]
# <h1 style="color:#AF1010;">VI-Visualizing:</h1>

# %% [markdown]
# **Lets visualize the number of players send by the country on each event vs the number of medals they recieve:**

# %%
# we are now getting the number of players played in each event and each country
no_of_players_and_medal = olympics.groupby(['team','event']).agg({'id':'count','medal':'count'})
# sorting players by id
sorted_players = no_of_players_and_medal.sort_values('medal',ascending=False).head().reset_index()
print(sorted_players)
# Out:
#             team                        event   id  medal
# 0  United States  Ice Hockey Men's Ice Hockey  260    260
# 1         Canada  Ice Hockey Men's Ice Hockey  249    249
# 2          Italy      Football Men's Football  209    209
# 3         Brazil      Football Men's Football  186    186
# 4  United States  Basketball Men's Basketball  174    174

# %%
# lets visualize our data

import matplotlib.pyplot as plt

fig , ax = plt.subplots()

# making scatter plot of number of player vs number of medal won in each country and events
ax.scatter(no_of_players_and_medal['medal'],no_of_players_and_medal['id'],color='green')
ax.set_xlabel('Number of medals')
ax.set_title('Highest medals won by a country in each event from 1896 to 2016')
ax.set_ylabel('Number of players')
# print(sorted_players['medal'].dtype)
# teams = ["Canada","Usa","Sweden","Usa","India"]
x = 220
y = 150

# making a annotation this is used to mark specific values on the plot so in this case we are marking top 5 plots using for loop
for index , team in sorted_players.iterrows():
    ax.annotate(team['team'],xy=(team['medal'],team['id']),xytext=(x,y),arrowprops={'arrowstyle':'->','color':'red'})
    y = y - 30
    x = x - 20
    
plt.show()

# %% [markdown]
# *=>USA is the country that received the biggest number of medals from 1896 to 2016.*

# %% [markdown]
# Let's now visualize first, second and third world countries and their respective performances in Olympics over the years:

# %%
# define a function that filters dataset to give desired records 
def olympics_by_countries(olympics, cnames):   
    filtered = olympics[olympics.team.isin(cnames)]
    filtered = filtered[filtered.medal.isin(["Gold", "Silver", "Bronze"])]
    return filtered[['medal', 'year', 'team']]

# use the displot function to visualize the medals won by countries India, China and United States throughout years
def plot(olympics):
    sns.displot(olympics, x="year", hue='team')

# call function olympics_by_countries and declare cnames to filter data and use function plot on the filtered data 
olympics = olympics_by_countries(olympics, ["India", "China", "United States"])
plot(olympics)

# %% [markdown]
# <h1 style="color:#AF1010;">V-Conclusion:</h1>

# %% [markdown]
#
#  *=>USA has been dominantly winning throughout the years while India is a poor performer majorly because of lesser participation rate. China, on the other hand, has been on the rise after the late 90s.*
